# %% [markdown]
# <a href="https://colab.research.google.com/github/JunaidRaza78/RI-Software-Predictive-models/blob/main/Code_Prediction_with_simple_formula.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def generate_code_single(purpose, age_start, age_end, gender):
    purpose = purpose[0] + purpose.split()[1][0]  # Extract the first letter of the purpose and the first letter after the space
    code = f"{purpose}{age_start}to{age_end}{gender[0]}"
    return code

# Example usage:
purpose = "weight gain"
age_start = 20
age_end = 58
gender = "male"

code = generate_code_single(purpose, age_start, age_end, gender)
print("Generated Code:", code)
# Out:
# Generated Code: wg20to58m

# %%
# Example usage:
purpose = "weight gain"
age_start = 40
age_end = 50
gender = "male"

code = generate_code_single(purpose, age_start, age_end, gender)
print("Generated Code:", code)
# Out:
# Generated Code: wg40to50m

# %%
import pandas as pd

def generate_code_single(purpose, age_start, age_end, gender):
    purpose = purpose[0] + purpose.split()[1][0]  # Extract the first letter of the purpose and the first letter after the space
    code = f"{purpose}{age_start}to{age_end}{gender[0]}"
    return code

# Read data from Excel file
data = pd.read_excel("/content/new model data.xlsx")

# Generate codes for each row
generated_codes = []
for index, row in data.iterrows():
    code = generate_code_single(row['purpose'], row['age_start'], row['age_end'], row['gender'])
    generated_codes.append(code)

# Write generated codes to a new Excel file
generated_data = pd.DataFrame({"Generated Code": generated_codes})
generated_data.to_excel("generated_codes.xlsx", index=False)

print("Generated codes saved to 'generated_codes.xlsx'")
# Out:
# Generated codes saved to 'generated_codes.xlsx'

# %%
generated_data
# Out:
#      Generated Code
# 0         wl10to10m
# 1         wl10to10f
# 2         wl10to11m
# 3         wl10to11f
# 4         wl10to12m
# ...             ...
# 3343      wg20to58f
# 3344      wg20to59m
# 3345      wg20to59f
# 3346      wg20to60m
# 3347      wg20to60f
#
# [3348 rows x 1 columns]

# %%
weight gain,
40,
50,
Male,
# Out:
#   File "<ipython-input-15-d72007358d95>", line 1
#     weight gain,
#            ^
# SyntaxError: invalid syntax
